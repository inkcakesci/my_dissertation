# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("data/kepler/baseline_periods_ls_acf.csv")

# 计算误差
df["err_ls"] = df["prot_ls"] - df["prot_label"]
df["err_acf"] = df["prot_acf"] - df["prot_label"]

# 简单统计
print("LS MAE:", np.nanmean(np.abs(df["err_ls"])))
print("ACF MAE:", np.nanmean(np.abs(df["err_acf"])))

# 画一下 prot_label vs prot_ls
plt.figure(figsize=(4,4))
plt.scatter(df["prot_label"], df["prot_ls"], s=10, alpha=0.7)
plt.plot([0,50],[0,50])
plt.xlabel("label Prot [d]")
plt.ylabel("LS Prot [d]")
plt.title("Label vs LS")
plt.tight_layout()
plt.show()

# Label vs ACF
plt.figure(figsize=(4,4))
plt.scatter(df["prot_label"], df["prot_acf"], s=10, alpha=0.7)
plt.plot([0,50],[0,50])
plt.xlabel("label Prot [d]")
plt.ylabel("ACF Prot [d]")
plt.title("Label vs ACF")
plt.tight_layout()
plt.show()
# Out:
# LS MAE: 16.506951208308834
# ACF MAE: 0.2131316283323298
