# %%
# %cd /Users/Zhuanz/Documents/Dissertation
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd()))

import src.analysis.baseline_plots as baseline_plots
baseline_plots.main()
# Out:
# /Users/Zhuanz/Documents/Dissertation
# [INFO] Loading baseline CSV from: /Users/Zhuanz/Documents/Dissertation/data/kepler/baseline_periods_ls_acf.csv
#
# === LS ===
# N = 216
# MAE (days): 17.109939194810707
# Median |err| (days): 18.03719759667394
# Median relative error: 0.8298569921366897
# Frac(|err|/P < 10%): 0.2175925925925926
# Frac(|err|/P < 20%): 0.25925925925925924
#
# === ACF ===
# N = 38
# MAE (days): 0.9774943308593119
# Median |err| (days): 0.3264925785812087
# Median relative error: 0.033172968095206146
# Frac(|err|/P < 10%): 0.9210526315789473
# Frac(|err|/P < 20%): 0.9736842105263158
#
# === GPS ===
# N = 214
# MAE (days): 9.300012862188602
# Median |err| (days): 4.9580886287625425
# Median relative error: 0.17117494265354993
# Frac(|err|/P < 10%): 0.102803738317757
# Frac(|err|/P < 20%): 0.5327102803738317
#
# === QP-GP ===
# N = 216
# MAE (days): 4.102122081320585
# Median |err| (days): 2.0789032809197465
# Median relative error: 0.15753085778018378
# ...

# %%
import src.analysis.npz_overview as npz_overview
npz_overview.main()
# Out:
# [INFO] Found 216 npz files in /Users/Zhuanz/Documents/Dissertation/data/kepler/lightcurves
# [INFO] Overview rows = 216; success=216, fail=0
# [INFO] Merged with catalog. Columns now: ['kic', 'n_points', 'time_span_days', 'cadence_days', 'cadence_minutes', 'flux_median', 'flux_std', 'prot', 'teff']
# [INFO] Saved overview CSV to: /Users/Zhuanz/Documents/Dissertation/data/kepler/lc_overview.csv
#
# === Basic overview stats ===
# n_points:
#   N          = 216
#   median     = 64793.000
#   mean       = 61116.231
#   min / max  = 32949.000 / 65268.000
# time_span_days:
#   N          = 216
#   median     = 1459.489
#   mean       = 1434.497
#   min / max  = 831.853 / 1470.463
# cadence_minutes:
#   N          = 216
#   median     = 29.424
#   mean       = 29.424
#   min / max  = 29.424 / 29.425
