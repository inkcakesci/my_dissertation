# %%
# %cd /Users/Zhuanz/Documents/Dissertation
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd()))

import src.analysis.baseline_plots as baseline_plots
baseline_plots.main()
# Out:
# === LS ===
# N = 192
# MAE (days): 17.4095777865616
# Median |err| (days): 18.644852218028447
# Median relative error: 0.8592884816968224
# Frac(|err|/P < 10%): 0.203125
# Frac(|err|/P < 20%): 0.24479166666666666
#
# === ACF ===
# N = 32
# MAE (days): 0.9821228862934932
# Median |err| (days): 0.23921362417121372
# Median relative error: 0.033172968095206146
# Frac(|err|/P < 10%): 0.9375
# Frac(|err|/P < 20%): 0.96875
#
# === GPS ===
# N = 190
# MAE (days): 9.48592900897729
# Median |err| (days): 5.207525083612039
# Median relative error: 0.17352365265709763
# Frac(|err|/P < 10%): 0.10526315789473684
# Frac(|err|/P < 20%): 0.5157894736842106
#
# === QP-GP ===
# N = 192
# MAE (days): 4.337149857748746
# Median |err| (days): 2.234077380595056
# Median relative error: 0.16351881408685315
# Frac(|err|/P < 10%): 0.28125
# Frac(|err|/P < 20%): 0.609375
# /var/folders/6z/psq2rp4943n_kbt84tynb65m0000gp/T/ipykernel_3892/1038400083.py:159: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(abs_err_data, labels=labels, showfliers=True)

# %%
import src.analysis.npz_overview as npz_overview
npz_overview.main()
# Out:
# [INFO] Found 192 npz files in /Users/Zhuanz/Documents/Dissertation/data/kepler/lightcurves
# [INFO] Overview rows = 192; success=192, fail=0
# [INFO] Merged with catalog. Columns now: ['kic', 'n_points', 'time_span_days', 'cadence_days', 'cadence_minutes', 'flux_median', 'flux_std', 'prot', 'teff']
# [INFO] Saved overview CSV to: /Users/Zhuanz/Documents/Dissertation/data/kepler/lc_overview.csv
#
# === Basic overview stats ===
# n_points:
#   N          = 192
#   median     = 64793.000
#   mean       = 61262.776
#   min / max  = 32949.000 / 65267.000
# time_span_days:
#   N          = 192
#   median     = 1459.489
#   mean       = 1432.754
#   min / max  = 831.853 / 1470.463
# cadence_minutes:
#   N          = 192
#   median     = 29.424
#   mean       = 29.424
#   min / max  = 29.424 / 29.425
