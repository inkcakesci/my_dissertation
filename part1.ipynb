# %%
import sys
from pathlib import Path

# 确保在项目根目录下（有 src/ 的那一层）
# %cd /Users/Zhuanz/Documents/Dissertation

# 把项目根目录加进 sys.path，确保能 import src.XXX
import sys
sys.path.insert(0, str(Path.cwd()))

from src.traditional.run_baseline_periods import main

# 模拟命令行参数：["run_baseline_periods.py", "--max-targets", "50"]
sys.argv = ["run_baseline_periods.py", "--max-targets", "5"]
main()
# Out:
# /Users/Zhuanz/Documents/Dissertation
# [WARN] 未检测到 celerite2 / src.gp.qpgp，自动跳过 QP-GP 拟合。
# [INFO] Found 5 npz lightcurves in /Users/Zhuanz/Documents/Dissertation/data/kepler/lightcurves
#
# [INFO] Processing KIC 893647 (label Prot=8.829 d)
# [WARN] GPS method failed for KIC 893647: module 'scipy.signal' has no attribute 'cwt'
# [INFO] Skip QP-GP for this run (--skip-qpgp).
#
# [INFO] Processing KIC 2019900 (label Prot=5.975 d)
# [WARN] GPS method failed for KIC 2019900: module 'scipy.signal' has no attribute 'cwt'
# [INFO] Skip QP-GP for this run (--skip-qpgp).
#
# [INFO] Processing KIC 2556279 (label Prot=3.317 d)
# [WARN] GPS method failed for KIC 2556279: module 'scipy.signal' has no attribute 'cwt'
# [INFO] Skip QP-GP for this run (--skip-qpgp).
#
# [INFO] Processing KIC 2695222 (label Prot=3.702 d)
# [WARN] GPS method failed for KIC 2695222: module 'scipy.signal' has no attribute 'cwt'
# [INFO] Skip QP-GP for this run (--skip-qpgp).
#
# [INFO] Processing KIC 2831370 (label Prot=19.630 d)
# [WARN] GPS method failed for KIC 2831370: module 'scipy.signal' has no attribute 'cwt'
# [INFO] Skip QP-GP for this run (--skip-qpgp).
#
# [INFO] Saved baseline results to: /Users/Zhuanz/Documents/Dissertation/data/kepler/baseline_periods_ls_acf.csv
# [INFO] Total stars processed (rows in output) = 5
