# %%
import sys
from pathlib import Path

# 确保在项目根目录下（有 src/ 的那一层）
# %cd /Users/Zhuanz/Documents/Dissertation

# 把项目根目录加进 sys.path，确保能 import src.XXX
import sys
sys.path.insert(0, str(Path.cwd()))

from src.traditional.run_baseline_periods import main

# 模拟命令行参数：["run_baseline_periods.py", "--max-targets", "50"]
sys.argv = ["run_baseline_periods.py", "--max-targets", "500"]
main()
# Out:
# /Users/Zhuanz/Documents/Dissertation
# [INFO] Found 500 npz lightcurves in /Users/Zhuanz/Documents/Dissertation/data/kepler/lightcurves
#
# [INFO] Processing KIC 893647 (label Prot=8.829 d)
# [WARN] scipy.signal.morlet2 not found; falling back to local implementation.
# [INFO] QP-GP period = 9.6816 d (success=True)
#
# [INFO] Processing KIC 1725997 (label Prot=13.065 d)
# [INFO] QP-GP period = 16.8866 d (success=True)
#
# [INFO] Processing KIC 1849547 (label Prot=21.583 d)
# [INFO] QP-GP period = 39.1931 d (success=True)
#
# [INFO] Processing KIC 1865206 (label Prot=22.790 d)
# [INFO] QP-GP period = 36.2310 d (success=True)
#
# [INFO] Processing KIC 2018492 (label Prot=29.610 d)
# [INFO] QP-GP period = 37.5342 d (success=True)
#
# [INFO] Processing KIC 2019900 (label Prot=5.975 d)
# [INFO] QP-GP period = 7.9778 d (success=True)
#
# [INFO] Processing KIC 2140686 (label Prot=11.556 d)
# [INFO] QP-GP period = 11.9299 d (success=True)
#
# [INFO] Processing KIC 2158543 (label Prot=20.826 d)
# [INFO] QP-GP period = 21.2132 d (success=True)
#
# [INFO] Processing KIC 2443364 (label Prot=35.915 d)
# [INFO] QP-GP period = 34.2840 d (success=True)
#
# [INFO] Processing KIC 2444517 (label Prot=26.095 d)
# [INFO] QP-GP period = 36.2163 d (success=True)
#
# [INFO] Processing KIC 2556279 (label Prot=3.317 d)
# [INFO] QP-GP period = 3.3178 d (success=True)
#
# [INFO] Processing KIC 2695222 (label Prot=3.702 d)
# [INFO] QP-GP period = 4.9990 d (success=True)
#
# [INFO] Processing KIC 2712178 (label Prot=17.496 d)
# [INFO] QP-GP period = 20.4140 d (success=True)
#
# [INFO] Processing KIC 2831370 (label Prot=19.630 d)
# [INFO] QP-GP period = 22.0822 d (success=True)
#
# [INFO] Processing KIC 2832484 (label Prot=3.646 d)
# [INFO] QP-GP period = 4.6733 d (success=True)
#
# [INFO] Processing KIC 3217410 (label Prot=16.603 d)
# [INFO] QP-GP period = 20.1243 d (success=True)
#
# [INFO] Processing KIC 3222610 (label Prot=4.910 d)
# [INFO] QP-GP period = 6.0237 d (success=True)
#
# [INFO] Processing KIC 3236788 (label Prot=5.429 d)
# [INFO] QP-GP period = 6.8483 d (success=True)
#
# [INFO] Processing KIC 3237993 (label Prot=5.142 d)
# [INFO] QP-GP period = 7.0589 d (success=True)
#
# [INFO] Processing KIC 3239557 (label Prot=12.832 d)
# [INFO] QP-GP period = 16.0392 d (success=True)
#
# [INFO] Processing KIC 3242050 (label Prot=12.932 d)
# [INFO] QP-GP period = 14.5794 d (success=True)
#
# [INFO] Processing KIC 3247798 (label Prot=10.424 d)
# [INFO] QP-GP period = 11.5742 d (success=True)
#
# [INFO] Processing KIC 3327068 (label Prot=4.519 d)
# [INFO] QP-GP period = 5.2964 d (success=True)
#
# [INFO] Processing KIC 3328254 (label Prot=31.578 d)
# [INFO] QP-GP period = 38.9944 d (success=True)
#
# [INFO] Processing KIC 3328711 (label Prot=32.512 d)
# [INFO] QP-GP period = 38.5759 d (success=True)
#
# [INFO] Processing KIC 3330261 (label Prot=26.347 d)
# [INFO] QP-GP period = 38.6821 d (success=True)
#
# [INFO] Processing KIC 3342894 (label Prot=14.092 d)
# [INFO] QP-GP period = 14.9551 d (success=True)
#
# [INFO] Processing KIC 3353480 (label Prot=12.377 d)
# [INFO] QP-GP period = 13.3054 d (success=True)
#
# [INFO] Processing KIC 3353601 (label Prot=24.033 d)
# [INFO] QP-GP period = 39.1007 d (success=True)
#
# [INFO] Processing KIC 3356832 (label Prot=12.194 d)
# [INFO] QP-GP period = 14.4096 d (success=True)
#
# [INFO] Processing KIC 3448897 (label Prot=6.916 d)
# [INFO] QP-GP period = 9.4145 d (success=True)
#
# [INFO] Processing KIC 3526481 (label Prot=14.559 d)
# [INFO] QP-GP period = 13.4224 d (success=True)
#
# [INFO] Processing KIC 3531315 (label Prot=21.199 d)
# [INFO] QP-GP period = 37.6612 d (success=True)
#
# [INFO] Processing KIC 3540780 (label Prot=26.697 d)
# [INFO] QP-GP period = 36.9466 d (success=True)
#
# [INFO] Processing KIC 3545170 (label Prot=1.154 d)
# [INFO] QP-GP period = 1.1540 d (success=True)
#
# [INFO] Processing KIC 3557197 (label Prot=1.962 d)
# [INFO] QP-GP period = 2.9786 d (success=True)
#
# [INFO] Processing KIC 3648721 (label Prot=2.523 d)
# [INFO] QP-GP period = 4.2768 d (success=True)
#
# [INFO] Processing KIC 3733537 (label Prot=5.975 d)
# [INFO] QP-GP period = 5.9743 d (success=True)
#
# [INFO] Processing KIC 3742890 (label Prot=3.544 d)
# [INFO] QP-GP period = 3.5451 d (success=True)
#
# [INFO] Processing KIC 3755492 (label Prot=2.432 d)
# [INFO] QP-GP period = 2.9323 d (success=True)
#
# [INFO] Processing KIC 3831289 (label Prot=28.409 d)
# [INFO] QP-GP period = 37.2868 d (success=True)
#
# [INFO] Processing KIC 3832499 (label Prot=13.010 d)
# [INFO] QP-GP period = 18.8906 d (success=True)
#
# [INFO] Processing KIC 3842433 (label Prot=13.422 d)
# [INFO] QP-GP period = 14.9725 d (success=True)
#
# [INFO] Processing KIC 3850729 (label Prot=38.752 d)
# [INFO] QP-GP period = 38.7007 d (success=True)
#
# [INFO] Processing KIC 3863928 (label Prot=7.923 d)
# [INFO] QP-GP period = 9.1362 d (success=True)
#
# [INFO] Processing KIC 3869311 (label Prot=14.835 d)
# [INFO] QP-GP period = 15.0189 d (success=True)
#
# [INFO] Processing KIC 3938241 (label Prot=16.781 d)
# [INFO] QP-GP period = 16.9405 d (success=True)
#
# [INFO] Processing KIC 3946621 (label Prot=2.640 d)
# [INFO] QP-GP period = 3.5021 d (success=True)
#
# [INFO] Processing KIC 3970457 (label Prot=4.976 d)
# [INFO] QP-GP period = 5.7296 d (success=True)
#
# [INFO] Processing KIC 3974277 (label Prot=12.021 d)
# [INFO] QP-GP period = 13.6229 d (success=True)
#
# [INFO] Processing KIC 4042747 (label Prot=9.957 d)
# [INFO] QP-GP period = 12.0964 d (success=True)
#
# [INFO] Processing KIC 4047976 (label Prot=25.558 d)
# [INFO] QP-GP period = 34.4905 d (success=True)
#
# [INFO] Processing KIC 4075608 (label Prot=9.090 d)
# [INFO] QP-GP period = 10.1921 d (success=True)
#
# [INFO] Processing KIC 4076697 (label Prot=8.378 d)
# [INFO] QP-GP period = 9.6890 d (success=True)
#
# [INFO] Processing KIC 4158384 (label Prot=32.704 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 4176145 (label Prot=2.191 d)
# [INFO] QP-GP period = 2.7995 d (success=True)
#
# [INFO] Processing KIC 4176960 (label Prot=16.353 d)
# [INFO] QP-GP period = 18.9644 d (success=True)
#
# [INFO] Processing KIC 4178418 (label Prot=15.662 d)
# [INFO] QP-GP period = 17.4670 d (success=True)
#
# [INFO] Processing KIC 4269291 (label Prot=3.801 d)
# [INFO] QP-GP period = 4.1789 d (success=True)
#
# [INFO] Processing KIC 4275254 (label Prot=15.144 d)
# [INFO] QP-GP period = 17.7633 d (success=True)
#
# [INFO] Processing KIC 4351056 (label Prot=32.218 d)
# [INFO] QP-GP period = 35.3754 d (success=True)
#
# [INFO] Processing KIC 4355501 (label Prot=25.161 d)
# [INFO] QP-GP period = 37.7433 d (success=True)
#
# [INFO] Processing KIC 4357578 (label Prot=32.622 d)
# [INFO] QP-GP period = 39.6389 d (success=True)
#
# [INFO] Processing KIC 4375393 (label Prot=14.307 d)
# [INFO] QP-GP period = 15.4872 d (success=True)
#
# [INFO] Processing KIC 4379563 (label Prot=9.253 d)
# [INFO] QP-GP period = 11.1963 d (success=True)
#
# [INFO] Processing KIC 4381114 (label Prot=32.261 d)
# [INFO] QP-GP period = 35.9738 d (success=True)
#
# [INFO] Processing KIC 4381745 (label Prot=10.387 d)
# [INFO] QP-GP period = 11.4057 d (success=True)
#
# [INFO] Processing KIC 4385761 (label Prot=15.155 d)
# [INFO] QP-GP period = 16.6825 d (success=True)
#
# [INFO] Processing KIC 4480250 (label Prot=27.504 d)
# [INFO] QP-GP period = 36.2446 d (success=True)
#
# [INFO] Processing KIC 4480672 (label Prot=23.054 d)
# [INFO] QP-GP period = 35.4177 d (success=True)
#
# [INFO] Processing KIC 4540728 (label Prot=3.368 d)
# [INFO] QP-GP period = 3.3675 d (success=True)
#
# [INFO] Processing KIC 4545145 (label Prot=24.315 d)
# [INFO] QP-GP period = 24.0441 d (success=True)
#
# [INFO] Processing KIC 4569832 (label Prot=4.307 d)
# [INFO] QP-GP period = 5.1550 d (success=True)
#
# [INFO] Processing KIC 4585976 (label Prot=1.627 d)
# [INFO] QP-GP period = 1.6136 d (success=True)
#
# [INFO] Processing KIC 4640044 (label Prot=2.967 d)
# [INFO] QP-GP period = 4.2796 d (success=True)
#
# [INFO] Processing KIC 4651312 (label Prot=29.427 d)
# [INFO] QP-GP period = 39.1280 d (success=True)
#
# [INFO] Processing KIC 4659608 (label Prot=28.737 d)
# [INFO] QP-GP period = 36.0704 d (success=True)
#
# [INFO] Processing KIC 4677281 (label Prot=5.730 d)
# [INFO] QP-GP period = 6.2000 d (success=True)
#
# [INFO] Processing KIC 4679110 (label Prot=28.004 d)
# [INFO] QP-GP period = 35.1320 d (success=True)
#
# [INFO] Processing KIC 4738722 (label Prot=13.569 d)
# [INFO] QP-GP period = 14.6247 d (success=True)
#
# [INFO] Processing KIC 4755493 (label Prot=18.914 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 4757871 (label Prot=30.119 d)
# [INFO] QP-GP period = 35.3783 d (success=True)
#
# [INFO] Processing KIC 4818236 (label Prot=13.410 d)
# [INFO] QP-GP period = 13.7303 d (success=True)
#
# [INFO] Processing KIC 4826941 (label Prot=3.485 d)
# [INFO] QP-GP period = 3.7559 d (success=True)
#
# [INFO] Processing KIC 4831198 (label Prot=3.745 d)
# [INFO] QP-GP period = 3.8282 d (success=True)
#
# [INFO] Processing KIC 4838459 (label Prot=6.806 d)
# [INFO] QP-GP period = 8.0311 d (success=True)
#
# [INFO] Processing KIC 4845559 (label Prot=16.324 d)
# [INFO] QP-GP period = 18.7983 d (success=True)
#
# [INFO] Processing KIC 4904088 (label Prot=2.529 d)
# [INFO] QP-GP period = 2.5287 d (success=True)
#
# [INFO] Processing KIC 4907576 (label Prot=27.739 d)
# [INFO] QP-GP period = 35.9753 d (success=True)
#
# [INFO] Processing KIC 4909473 (label Prot=4.406 d)
# [INFO] QP-GP period = 4.4085 d (success=True)
#
# [INFO] Processing KIC 4914771 (label Prot=13.026 d)
# [INFO] QP-GP period = 14.8200 d (success=True)
#
# [INFO] Processing KIC 4918333 (label Prot=19.854 d)
# [INFO] QP-GP period = 21.7440 d (success=True)
#
# [INFO] Processing KIC 4929747 (label Prot=6.029 d)
# [INFO] QP-GP period = 6.5765 d (success=True)
#
# [INFO] Processing KIC 4931864 (label Prot=1.569 d)
# [INFO] QP-GP period = 1.5690 d (success=True)
#
# [INFO] Processing KIC 5004687 (label Prot=27.647 d)
# [INFO] QP-GP period = 38.2738 d (success=True)
#
# [INFO] Processing KIC 5015744 (label Prot=23.066 d)
# [INFO] QP-GP period = 36.8231 d (success=True)
#
# [INFO] Processing KIC 5031916 (label Prot=4.741 d)
# [INFO] QP-GP period = 5.0762 d (success=True)
#
# [INFO] Processing KIC 5032822 (label Prot=15.397 d)
# [INFO] QP-GP period = 18.1286 d (success=True)
#
# [INFO] Processing KIC 5033905 (label Prot=27.555 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5040378 (label Prot=25.799 d)
# [INFO] QP-GP period = 36.3453 d (success=True)
#
# [INFO] Processing KIC 5042015 (label Prot=4.549 d)
# [INFO] QP-GP period = 5.4213 d (success=True)
#
# [INFO] Processing KIC 5095980 (label Prot=19.678 d)
# [INFO] QP-GP period = 23.4953 d (success=True)
#
# [INFO] Processing KIC 5105118 (label Prot=15.304 d)
# [INFO] QP-GP period = 16.4624 d (success=True)
#
# [INFO] Processing KIC 5114994 (label Prot=6.276 d)
# [INFO] QP-GP period = 6.6568 d (success=True)
#
# [INFO] Processing KIC 5167837 (label Prot=23.014 d)
# [INFO] QP-GP period = 36.7947 d (success=True)
#
# [INFO] Processing KIC 5171909 (label Prot=22.140 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5177000 (label Prot=11.439 d)
# [INFO] QP-GP period = 12.6839 d (success=True)
#
# [INFO] Processing KIC 5179724 (label Prot=10.524 d)
# [INFO] QP-GP period = 12.5559 d (success=True)
#
# [INFO] Processing KIC 5194631 (label Prot=17.975 d)
# [INFO] QP-GP period = 20.0505 d (success=True)
#
# [INFO] Processing KIC 5195727 (label Prot=23.496 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5196646 (label Prot=1.044 d)
# [INFO] QP-GP period = 1.0440 d (success=True)
#
# [INFO] Processing KIC 5197876 (label Prot=9.463 d)
# [INFO] QP-GP period = 11.2720 d (success=True)
#
# [INFO] Processing KIC 5207655 (label Prot=2.546 d)
# [INFO] QP-GP period = 2.9488 d (success=True)
#
# [INFO] Processing KIC 5254309 (label Prot=15.000 d)
# [INFO] QP-GP period = 17.9145 d (success=True)
#
# [INFO] Processing KIC 5257177 (label Prot=15.505 d)
# [INFO] QP-GP period = 16.5142 d (success=True)
#
# [INFO] Processing KIC 5270719 (label Prot=9.637 d)
# [INFO] QP-GP period = 11.1429 d (success=True)
#
# [INFO] Processing KIC 5271270 (label Prot=21.909 d)
# [INFO] QP-GP period = 39.0378 d (success=True)
#
# [INFO] Processing KIC 5283113 (label Prot=20.208 d)
# [INFO] QP-GP period = 22.4562 d (success=True)
#
# [INFO] Processing KIC 5297346 (label Prot=9.375 d)
# [INFO] QP-GP period = 9.4873 d (success=True)
#
# [INFO] Processing KIC 5301441 (label Prot=13.034 d)
# [INFO] QP-GP period = 14.4800 d (success=True)
#
# [INFO] Processing KIC 5304359 (label Prot=13.368 d)
# [INFO] QP-GP period = 14.9890 d (success=True)
#
# [INFO] Processing KIC 5307845 (label Prot=32.845 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5308270 (label Prot=8.671 d)
# [INFO] QP-GP period = 9.8025 d (success=True)
#
# [INFO] Processing KIC 5339846 (label Prot=25.511 d)
# [INFO] QP-GP period = 35.9959 d (success=True)
#
# [INFO] Processing KIC 5351136 (label Prot=1.385 d)
# [INFO] QP-GP period = 1.7067 d (success=True)
#
# [INFO] Processing KIC 5354845 (label Prot=7.902 d)
# [INFO] QP-GP period = 12.3502 d (success=True)
#
# [INFO] Processing KIC 5373525 (label Prot=32.337 d)
# [INFO] QP-GP period = 33.9323 d (success=True)
#
# [INFO] Processing KIC 5374723 (label Prot=28.015 d)
# [INFO] QP-GP period = 36.4563 d (success=True)
#
# [INFO] Processing KIC 5392431 (label Prot=9.592 d)
# [INFO] QP-GP period = 11.1162 d (success=True)
#
# [INFO] Processing KIC 5450334 (label Prot=38.705 d)
# [INFO] QP-GP period = 39.9809 d (success=True)
#
# [INFO] Processing KIC 5471091 (label Prot=1.089 d)
# [INFO] QP-GP period = 1.0890 d (success=True)
#
# [INFO] Processing KIC 5473087 (label Prot=18.717 d)
# [INFO] QP-GP period = 21.2458 d (success=True)
#
# [INFO] Processing KIC 5479971 (label Prot=7.775 d)
# [INFO] QP-GP period = 8.7014 d (success=True)
#
# [INFO] Processing KIC 5480080 (label Prot=12.682 d)
# [INFO] QP-GP period = 14.9513 d (success=True)
#
# [INFO] Processing KIC 5481482 (label Prot=1.068 d)
# [INFO] QP-GP period = 1.0680 d (success=True)
#
# [INFO] Processing KIC 5482415 (label Prot=1.869 d)
# [INFO] QP-GP period = 1.8691 d (success=True)
#
# [INFO] Processing KIC 5512513 (label Prot=0.781 d)
# [INFO] QP-GP period = 0.7811 d (success=True)
#
# [INFO] Processing KIC 5528100 (label Prot=12.565 d)
# [INFO] QP-GP period = 16.2599 d (success=True)
#
# [INFO] Processing KIC 5544227 (label Prot=1.757 d)
# [INFO] QP-GP period = 1.7571 d (success=True)
#
# [INFO] Processing KIC 5554125 (label Prot=20.911 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5597401 (label Prot=1.618 d)
# [INFO] QP-GP period = 1.6171 d (success=True)
#
# [INFO] Processing KIC 5597879 (label Prot=17.972 d)
# [INFO] QP-GP period = 19.2641 d (success=True)
#
# [INFO] Processing KIC 5601728 (label Prot=26.130 d)
# [INFO] QP-GP period = 36.4904 d (success=True)
#
# [INFO] Processing KIC 5609446 (label Prot=16.374 d)
# [INFO] QP-GP period = 19.0312 d (success=True)
#
# [INFO] Processing KIC 5613532 (label Prot=26.146 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5629172 (label Prot=21.222 d)
# [INFO] QP-GP period = 23.0521 d (success=True)
#
# [INFO] Processing KIC 5632118 (label Prot=19.441 d)
# [INFO] QP-GP period = 20.9818 d (success=True)
#
# [INFO] Processing KIC 5640284 (label Prot=17.204 d)
# [INFO] QP-GP period = 19.0824 d (success=True)
#
# [INFO] Processing KIC 5648350 (label Prot=14.488 d)
# [INFO] QP-GP period = 16.6727 d (success=True)
#
# [INFO] Processing KIC 5693894 (label Prot=16.143 d)
# [INFO] QP-GP period = 18.1027 d (success=True)
#
# [INFO] Processing KIC 5696590 (label Prot=3.237 d)
# [INFO] QP-GP period = 3.2372 d (success=True)
#
# [INFO] Processing KIC 5715752 (label Prot=7.554 d)
# [INFO] QP-GP period = 8.2642 d (success=True)
#
# [INFO] Processing KIC 5716131 (label Prot=14.118 d)
# [INFO] QP-GP period = 15.6140 d (success=True)
#
# [INFO] Processing KIC 5718325 (label Prot=27.065 d)
# [INFO] QP-GP period = 26.1435 d (success=True)
#
# [INFO] Processing KIC 5722533 (label Prot=26.305 d)
# [INFO] QP-GP period = 28.8567 d (success=True)
#
# [INFO] Processing KIC 5723318 (label Prot=2.526 d)
# [INFO] QP-GP period = 3.1535 d (success=True)
#
# [INFO] Processing KIC 5773135 (label Prot=27.643 d)
# [INFO] QP-GP period = 35.0510 d (success=True)
#
# [INFO] Processing KIC 5788112 (label Prot=34.901 d)
# [INFO] QP-GP period = 37.8848 d (success=True)
#
# [INFO] Processing KIC 5790645 (label Prot=31.097 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5791190 (label Prot=18.454 d)
# [INFO] QP-GP period = 20.6907 d (success=True)
#
# [INFO] Processing KIC 5857836 (label Prot=0.555 d)
# [INFO] QP-GP period = 0.5550 d (success=True)
#
# [INFO] Processing KIC 5876377 (label Prot=10.837 d)
# [INFO] QP-GP period = 11.2074 d (success=True)
#
# [INFO] Processing KIC 5881276 (label Prot=8.495 d)
# [INFO] QP-GP period = 9.8670 d (success=True)
#
# [INFO] Processing KIC 5900600 (label Prot=14.043 d)
# [INFO] QP-GP period = 16.2825 d (success=True)
#
# [INFO] Processing KIC 5907881 (label Prot=21.490 d)
# [INFO] QP-GP period = 35.3183 d (success=True)
#
# [INFO] Processing KIC 5937679 (label Prot=34.868 d)
# [INFO] QP-GP period = 37.7771 d (success=True)
#
# [INFO] Processing KIC 5939072 (label Prot=23.728 d)
# [INFO] QP-GP period = 27.2951 d (success=True)
#
# [INFO] Processing KIC 5939163 (label Prot=22.079 d)
# [INFO] QP-GP period = 37.1047 d (success=True)
#
# [INFO] Processing KIC 5939736 (label Prot=31.055 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5950604 (label Prot=8.629 d)
# [INFO] QP-GP period = 9.4084 d (success=True)
#
# [INFO] Processing KIC 5953556 (label Prot=8.999 d)
# [INFO] QP-GP period = 9.9586 d (success=True)
#
# [INFO] Processing KIC 5964734 (label Prot=19.405 d)
# [INFO] QP-GP period = 18.7871 d (success=True)
#
# [INFO] Processing KIC 5966921 (label Prot=5.155 d)
# [INFO] QP-GP period = 5.1615 d (success=True)
#
# [INFO] Processing KIC 5977477 (label Prot=27.810 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 5980361 (label Prot=21.889 d)
# [INFO] QP-GP period = 24.8664 d (success=True)
#
# [INFO] Processing KIC 6021998 (label Prot=3.034 d)
# [INFO] QP-GP period = 3.4654 d (success=True)
#
# [INFO] Processing KIC 6024170 (label Prot=6.671 d)
# [INFO] QP-GP period = 7.6467 d (success=True)
#
# [INFO] Processing KIC 6038355 (label Prot=8.089 d)
# [INFO] QP-GP period = 8.1019 d (success=True)
#
# [INFO] Processing KIC 6044117 (label Prot=17.834 d)
# [INFO] QP-GP period = 18.1966 d (success=True)
#
# [INFO] Processing KIC 6044768 (label Prot=35.231 d)
# [INFO] QP-GP period = 36.8736 d (success=True)
#
# [INFO] Processing KIC 6045006 (label Prot=18.546 d)
# [INFO] QP-GP period = 21.3135 d (success=True)
#
# [INFO] Processing KIC 6101173 (label Prot=25.463 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6107266 (label Prot=4.379 d)
# [INFO] QP-GP period = 4.5560 d (success=True)
#
# [INFO] Processing KIC 6111127 (label Prot=21.569 d)
# [INFO] QP-GP period = 38.2314 d (success=True)
#
# [INFO] Processing KIC 6115165 (label Prot=12.744 d)
# [INFO] QP-GP period = 13.4518 d (success=True)
#
# [INFO] Processing KIC 6123205 (label Prot=4.337 d)
# [INFO] QP-GP period = 5.0738 d (success=True)
#
# [INFO] Processing KIC 6144190 (label Prot=11.489 d)
# [INFO] QP-GP period = 13.6784 d (success=True)
#
# [INFO] Processing KIC 6147636 (label Prot=30.940 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6149138 (label Prot=2.436 d)
# [INFO] QP-GP period = 2.5838 d (success=True)
#
# [INFO] Processing KIC 6150118 (label Prot=27.552 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6195999 (label Prot=2.890 d)
# [INFO] QP-GP period = 3.6026 d (success=True)
#
# [INFO] Processing KIC 6204846 (label Prot=13.195 d)
# [INFO] QP-GP period = 16.1737 d (success=True)
#
# [INFO] Processing KIC 6220300 (label Prot=20.305 d)
# [INFO] QP-GP period = 22.7888 d (success=True)
#
# [INFO] Processing KIC 6231124 (label Prot=5.527 d)
# [INFO] QP-GP period = 6.0421 d (success=True)
#
# [INFO] Processing KIC 6232989 (label Prot=28.986 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6265065 (label Prot=25.958 d)
# [INFO] QP-GP period = 29.1024 d (success=True)
#
# [INFO] Processing KIC 6279323 (label Prot=23.019 d)
# [INFO] QP-GP period = 36.8037 d (success=True)
#
# [INFO] Processing KIC 6286296 (label Prot=32.697 d)
# [INFO] QP-GP period = 34.0702 d (success=True)
#
# [INFO] Processing KIC 6290740 (label Prot=15.164 d)
# [INFO] QP-GP period = 15.7254 d (success=True)
#
# [INFO] Processing KIC 6290811 (label Prot=2.828 d)
# [INFO] QP-GP period = 3.4722 d (success=True)
#
# [INFO] Processing KIC 6314495 (label Prot=15.463 d)
# [INFO] QP-GP period = 16.5068 d (success=True)
#
# [INFO] Processing KIC 6345900 (label Prot=31.632 d)
# [INFO] QP-GP period = 35.6828 d (success=True)
#
# [INFO] Processing KIC 6358701 (label Prot=24.837 d)
# [INFO] QP-GP period = 36.9994 d (success=True)
#
# [INFO] Processing KIC 6358735 (label Prot=33.541 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6362609 (label Prot=13.298 d)
# [INFO] QP-GP period = 14.0039 d (success=True)
#
# [INFO] Processing KIC 6369237 (label Prot=22.953 d)
# [INFO] QP-GP period = 37.4966 d (success=True)
#
# [INFO] Processing KIC 6372718 (label Prot=18.915 d)
# [INFO] QP-GP period = 20.9580 d (success=True)
#
# [INFO] Processing KIC 6423605 (label Prot=30.751 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6424778 (label Prot=18.217 d)
# [INFO] QP-GP period = 20.8226 d (success=True)
#
# [INFO] Processing KIC 6425024 (label Prot=24.232 d)
# [INFO] QP-GP period = 26.7880 d (success=True)
#
# [INFO] Processing KIC 6428698 (label Prot=28.813 d)
# [INFO] QP-GP period = 27.5965 d (success=True)
#
# [INFO] Processing KIC 6431431 (label Prot=4.516 d)
# [INFO] QP-GP period = 5.7052 d (success=True)
#
# [INFO] Processing KIC 6442058 (label Prot=13.293 d)
# [INFO] QP-GP period = 14.8633 d (success=True)
#
# [INFO] Processing KIC 6444981 (label Prot=11.943 d)
# [INFO] QP-GP period = 13.9776 d (success=True)
#
# [INFO] Processing KIC 6445061 (label Prot=21.397 d)
# [INFO] QP-GP period = 34.3229 d (success=True)
#
# [INFO] Processing KIC 6445537 (label Prot=1.659 d)
# [INFO] QP-GP period = 2.1649 d (success=True)
#
# [INFO] Processing KIC 6450960 (label Prot=18.905 d)
# [INFO] QP-GP period = 20.8757 d (success=True)
#
# [INFO] Processing KIC 6451979 (label Prot=4.964 d)
# [INFO] QP-GP period = 7.1123 d (success=True)
#
# [INFO] Processing KIC 6466312 (label Prot=2.970 d)
# [INFO] QP-GP period = 3.1607 d (success=True)
#
# [INFO] Processing KIC 6467490 (label Prot=2.279 d)
# [INFO] QP-GP period = 2.2791 d (success=True)
#
# [INFO] Processing KIC 6515731 (label Prot=35.790 d)
# [INFO] QP-GP period = 37.2193 d (success=True)
#
# [INFO] Processing KIC 6525026 (label Prot=13.121 d)
# [INFO] QP-GP period = 14.2268 d (success=True)
#
# [INFO] Processing KIC 6529860 (label Prot=11.963 d)
# [INFO] QP-GP period = 14.6632 d (success=True)
#
# [INFO] Processing KIC 6545529 (label Prot=32.325 d)
# [INFO] QP-GP period = 37.5065 d (success=True)
#
# [INFO] Processing KIC 6548429 (label Prot=7.632 d)
# [INFO] QP-GP period = 9.3178 d (success=True)
#
# [INFO] Processing KIC 6599993 (label Prot=8.698 d)
# [INFO] QP-GP period = 12.8762 d (success=True)
#
# [INFO] Processing KIC 6610530 (label Prot=33.622 d)
# [INFO] QP-GP period = 34.0575 d (success=True)
#
# [INFO] Processing KIC 6611476 (label Prot=7.385 d)
# [INFO] QP-GP period = 8.1531 d (success=True)
#
# [INFO] Processing KIC 6611775 (label Prot=10.045 d)
# [INFO] QP-GP period = 10.0450 d (success=True)
#
# [INFO] Processing KIC 6615161 (label Prot=18.834 d)
# [INFO] QP-GP period = 19.5718 d (success=True)
#
# [INFO] Processing KIC 6696289 (label Prot=27.499 d)
# [INFO] QP-GP period = 33.8972 d (success=True)
#
# [INFO] Processing KIC 6699346 (label Prot=1.338 d)
# [INFO] QP-GP period = 1.3380 d (success=True)
#
# [INFO] Processing KIC 6706050 (label Prot=7.352 d)
# [INFO] QP-GP period = 8.3563 d (success=True)
#
# [INFO] Processing KIC 6717610 (label Prot=11.411 d)
# [INFO] QP-GP period = 13.3394 d (success=True)
#
# [INFO] Processing KIC 6720029 (label Prot=14.885 d)
# [INFO] QP-GP period = 17.0536 d (success=True)
#
# [INFO] Processing KIC 6720216 (label Prot=25.645 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6777781 (label Prot=19.530 d)
# [INFO] QP-GP period = 19.9599 d (success=True)
#
# [INFO] Processing KIC 6803898 (label Prot=6.328 d)
# [INFO] QP-GP period = 6.7084 d (success=True)
#
# [INFO] Processing KIC 6803967 (label Prot=10.735 d)
# [INFO] QP-GP period = 10.7272 d (success=True)
#
# [INFO] Processing KIC 6836201 (label Prot=20.116 d)
# [INFO] QP-GP period = 22.1963 d (success=True)
#
# [INFO] Processing KIC 6836871 (label Prot=13.841 d)
# [INFO] QP-GP period = 13.3919 d (success=True)
#
# [INFO] Processing KIC 6867551 (label Prot=27.635 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 6869776 (label Prot=25.269 d)
# [INFO] QP-GP period = 37.9636 d (success=True)
#
# [INFO] Processing KIC 6878459 (label Prot=9.124 d)
# [INFO] QP-GP period = 10.4679 d (success=True)
#
# [INFO] Processing KIC 6880179 (label Prot=4.944 d)
# [INFO] QP-GP period = 6.2530 d (success=True)
#
# [INFO] Processing KIC 6939305 (label Prot=1.698 d)
# [INFO] QP-GP period = 1.6980 d (success=True)
#
# [INFO] Processing KIC 6940255 (label Prot=9.827 d)
# [INFO] QP-GP period = 11.5371 d (success=True)
#
# [INFO] Processing KIC 6946839 (label Prot=31.680 d)
# [INFO] QP-GP period = 33.7326 d (success=True)
#
# [INFO] Processing KIC 6946871 (label Prot=2.203 d)
# [INFO] QP-GP period = 2.2030 d (success=True)
#
# [INFO] Processing KIC 6947058 (label Prot=9.673 d)
# [INFO] QP-GP period = 11.6202 d (success=True)
#
# [INFO] Processing KIC 6974809 (label Prot=9.806 d)
# [INFO] QP-GP period = 10.8894 d (success=True)
#
# [INFO] Processing KIC 7022598 (label Prot=19.413 d)
# [INFO] QP-GP period = 19.4255 d (success=True)
#
# [INFO] Processing KIC 7024901 (label Prot=9.261 d)
# [INFO] QP-GP period = 9.2529 d (success=True)
#
# [INFO] Processing KIC 7060028 (label Prot=2.175 d)
# [INFO] QP-GP period = 2.9077 d (success=True)
#
# [INFO] Processing KIC 7060301 (label Prot=12.463 d)
# [INFO] QP-GP period = 14.6083 d (success=True)
#
# [INFO] Processing KIC 7102876 (label Prot=10.932 d)
# [INFO] QP-GP period = 12.7744 d (success=True)
#
# [INFO] Processing KIC 7108863 (label Prot=12.319 d)
# [INFO] QP-GP period = 16.0633 d (success=True)
#
# [INFO] Processing KIC 7133789 (label Prot=30.099 d)
# [INFO] QP-GP period = 39.1191 d (success=True)
#
# [INFO] Processing KIC 7177517 (label Prot=1.181 d)
# [INFO] QP-GP period = 2.9253 d (success=True)
#
# [INFO] Processing KIC 7200457 (label Prot=16.428 d)
# [INFO] QP-GP period = 19.6701 d (success=True)
#
# [INFO] Processing KIC 7201995 (label Prot=8.683 d)
# [INFO] QP-GP period = 9.5648 d (success=True)
#
# [INFO] Processing KIC 7202027 (label Prot=14.407 d)
# [INFO] QP-GP period = 17.1634 d (success=True)
#
# [INFO] Processing KIC 7257681 (label Prot=19.338 d)
# [INFO] QP-GP period = 22.1403 d (success=True)
#
# [INFO] Processing KIC 7267381 (label Prot=23.324 d)
# [INFO] QP-GP period = 37.5614 d (success=True)
#
# [INFO] Processing KIC 7282194 (label Prot=23.638 d)
# [INFO] QP-GP period = 36.2748 d (success=True)
#
# [INFO] Processing KIC 7283959 (label Prot=10.038 d)
# [INFO] QP-GP period = 12.8632 d (success=True)
#
# [INFO] Processing KIC 7284498 (label Prot=17.514 d)
# [INFO] QP-GP period = 17.1819 d (success=True)
#
# [INFO] Processing KIC 7301333 (label Prot=27.947 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 7335938 (label Prot=13.694 d)
# [INFO] QP-GP period = 15.8655 d (success=True)
#
# [INFO] Processing KIC 7364934 (label Prot=16.433 d)
# [INFO] QP-GP period = 19.3047 d (success=True)
#
# [INFO] Processing KIC 7422281 (label Prot=17.931 d)
# [INFO] QP-GP period = 21.2457 d (success=True)
#
# [INFO] Processing KIC 7428469 (label Prot=22.029 d)
# [INFO] QP-GP period = 37.0318 d (success=True)
#
# [INFO] Processing KIC 7434449 (label Prot=10.949 d)
# [INFO] QP-GP period = 12.3244 d (success=True)
#
# [INFO] Processing KIC 7448760 (label Prot=8.642 d)
# [INFO] QP-GP period = 10.4429 d (success=True)
#
# [INFO] Processing KIC 7451094 (label Prot=1.856 d)
# [INFO] QP-GP period = 1.8560 d (success=True)
#
# [INFO] Processing KIC 7456981 (label Prot=32.062 d)
# [INFO] QP-GP period = 34.1350 d (success=True)
#
# [INFO] Processing KIC 7464361 (label Prot=1.792 d)
# [INFO] QP-GP period = 1.7920 d (success=True)
#
# [INFO] Processing KIC 7466155 (label Prot=8.185 d)
# [INFO] QP-GP period = 8.9740 d (success=True)
#
# [INFO] Processing KIC 7502671 (label Prot=2.331 d)
# [INFO] QP-GP period = 2.3294 d (success=True)
#
# [INFO] Processing KIC 7509496 (label Prot=9.720 d)
# [INFO] QP-GP period = 9.4240 d (success=True)
#
# [INFO] Processing KIC 7513681 (label Prot=34.032 d)
# [INFO] QP-GP period = 36.7798 d (success=True)
#
# [INFO] Processing KIC 7521850 (label Prot=33.571 d)
# [INFO] QP-GP period = 38.8909 d (success=True)
#
# [INFO] Processing KIC 7529513 (label Prot=17.526 d)
# [INFO] QP-GP period = 19.9735 d (success=True)
#
# [INFO] Processing KIC 7544521 (label Prot=7.371 d)
# [INFO] QP-GP period = 9.3972 d (success=True)
#
# [INFO] Processing KIC 7551695 (label Prot=3.915 d)
# [INFO] QP-GP period = 4.5348 d (success=True)
#
# [INFO] Processing KIC 7552119 (label Prot=2.991 d)
# [INFO] QP-GP period = 3.1691 d (success=True)
#
# [INFO] Processing KIC 7586560 (label Prot=21.738 d)
# [INFO] QP-GP period = 37.4088 d (success=True)
#
# [INFO] Processing KIC 7594770 (label Prot=2.648 d)
# [INFO] QP-GP period = 2.6486 d (success=True)
#
# [INFO] Processing KIC 7596634 (label Prot=4.565 d)
# [INFO] QP-GP period = 4.5645 d (success=True)
#
# [INFO] Processing KIC 7627107 (label Prot=31.319 d)
# [INFO] QP-GP period = 36.2156 d (success=True)
#
# [INFO] Processing KIC 7668857 (label Prot=9.183 d)
# [INFO] QP-GP period = 11.1585 d (success=True)
#
# [INFO] Processing KIC 7691204 (label Prot=20.442 d)
# [INFO] QP-GP period = 37.2442 d (success=True)
#
# [INFO] Processing KIC 7703219 (label Prot=19.996 d)
# [INFO] QP-GP period = 22.8742 d (success=True)
#
# [INFO] Processing KIC 7707962 (label Prot=13.228 d)
# [INFO] QP-GP period = 14.2774 d (success=True)
#
# [INFO] Processing KIC 7739127 (label Prot=34.829 d)
# [INFO] QP-GP period = 39.6063 d (success=True)
#
# [INFO] Processing KIC 7749368 (label Prot=19.565 d)
# [INFO] QP-GP period = 34.3724 d (success=True)
#
# [INFO] Processing KIC 7750330 (label Prot=15.716 d)
# [INFO] QP-GP period = 19.9434 d (success=True)
#
# [INFO] Processing KIC 7751278 (label Prot=8.590 d)
# [INFO] QP-GP period = 10.5522 d (success=True)
#
# [INFO] Processing KIC 7756113 (label Prot=21.382 d)
# [INFO] QP-GP period = 34.4504 d (success=True)
#
# [INFO] Processing KIC 7771108 (label Prot=26.359 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 7772109 (label Prot=15.890 d)
# [INFO] QP-GP period = 18.6883 d (success=True)
#
# [INFO] Processing KIC 7773885 (label Prot=13.143 d)
# [INFO] QP-GP period = 16.3077 d (success=True)
#
# [INFO] Processing KIC 7812977 (label Prot=16.459 d)
# [INFO] QP-GP period = 17.8755 d (success=True)
#
# [INFO] Processing KIC 7817584 (label Prot=13.743 d)
# [INFO] QP-GP period = 15.6386 d (success=True)
#
# [INFO] Processing KIC 7830340 (label Prot=20.904 d)
# [INFO] QP-GP period = 36.9815 d (success=True)
#
# [INFO] Processing KIC 7838066 (label Prot=3.077 d)
# [INFO] QP-GP period = 3.4903 d (success=True)
#
# [INFO] Processing KIC 7838375 (label Prot=8.391 d)
# [INFO] QP-GP period = 10.1578 d (success=True)
#
# [INFO] Processing KIC 7870750 (label Prot=2.791 d)
# [INFO] QP-GP period = 5.2652 d (success=True)
#
# [INFO] Processing KIC 7886049 (label Prot=1.497 d)
# [INFO] QP-GP period = 1.8104 d (success=True)
#
# [INFO] Processing KIC 7900713 (label Prot=19.247 d)
# [INFO] QP-GP period = 36.8776 d (success=True)
#
# [INFO] Processing KIC 7906811 (label Prot=15.080 d)
# [INFO] QP-GP period = 15.5718 d (success=True)
#
# [INFO] Processing KIC 7909671 (label Prot=27.511 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 7916982 (label Prot=13.034 d)
# [INFO] QP-GP period = 13.7773 d (success=True)
#
# [INFO] Processing KIC 7939051 (label Prot=17.245 d)
# [INFO] QP-GP period = 17.7758 d (success=True)
#
# [INFO] Processing KIC 7973122 (label Prot=28.221 d)
# [INFO] QP-GP period = 28.0415 d (success=True)
#
# [INFO] Processing KIC 7975408 (label Prot=17.226 d)
# [INFO] QP-GP period = 19.6374 d (success=True)
#
# [INFO] Processing KIC 8008835 (label Prot=17.232 d)
# [INFO] QP-GP period = 20.1718 d (success=True)
#
# [INFO] Processing KIC 8037466 (label Prot=18.727 d)
# [INFO] QP-GP period = 21.7093 d (success=True)
#
# [INFO] Processing KIC 8039128 (label Prot=11.927 d)
# [INFO] QP-GP period = 15.7370 d (success=True)
#
# [INFO] Processing KIC 8043361 (label Prot=8.264 d)
# [INFO] QP-GP period = 8.9193 d (success=True)
#
# [INFO] Processing KIC 8053780 (label Prot=8.955 d)
# [INFO] QP-GP period = 11.1809 d (success=True)
#
# [INFO] Processing KIC 8058082 (label Prot=5.187 d)
# [INFO] QP-GP period = 5.7804 d (success=True)
#
# [INFO] Processing KIC 8081822 (label Prot=10.121 d)
# [INFO] QP-GP period = 11.8505 d (success=True)
#
# [INFO] Processing KIC 8090473 (label Prot=18.323 d)
# [INFO] QP-GP period = 21.2170 d (success=True)
#
# [INFO] Processing KIC 8105265 (label Prot=21.734 d)
# [INFO] QP-GP period = 37.0625 d (success=True)
#
# [INFO] Processing KIC 8114703 (label Prot=9.511 d)
# [INFO] QP-GP period = 9.4740 d (success=True)
#
# [INFO] Processing KIC 8146507 (label Prot=23.830 d)
# [INFO] QP-GP period = 37.4426 d (success=True)
#
# [INFO] Processing KIC 8151196 (label Prot=18.758 d)
# [INFO] QP-GP period = 19.2787 d (success=True)
#
# [INFO] Processing KIC 8153942 (label Prot=20.303 d)
# [INFO] QP-GP period = 22.7310 d (success=True)
#
# [INFO] Processing KIC 8161589 (label Prot=23.409 d)
# [INFO] QP-GP period = 39.2304 d (success=True)
#
# [INFO] Processing KIC 8162452 (label Prot=33.959 d)
# [INFO] QP-GP period = 39.1206 d (success=True)
#
# [INFO] Processing KIC 8175266 (label Prot=15.272 d)
# [INFO] QP-GP period = 16.1818 d (success=True)
#
# [INFO] Processing KIC 8179177 (label Prot=11.682 d)
# [INFO] QP-GP period = 12.2370 d (success=True)
#
# [INFO] Processing KIC 8181016 (label Prot=0.713 d)
# [INFO] QP-GP period = 1.8098 d (success=True)
#
# [INFO] Processing KIC 8182250 (label Prot=19.711 d)
# [INFO] QP-GP period = 36.5479 d (success=True)
#
# [INFO] Processing KIC 8195297 (label Prot=29.919 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 8197923 (label Prot=4.045 d)
# [INFO] QP-GP period = 5.0079 d (success=True)
#
# [INFO] Processing KIC 8211801 (label Prot=6.385 d)
# [INFO] QP-GP period = 7.6448 d (success=True)
#
# [INFO] Processing KIC 8233588 (label Prot=11.894 d)
# [INFO] QP-GP period = 12.8741 d (success=True)
#
# [INFO] Processing KIC 8240881 (label Prot=13.432 d)
# [INFO] QP-GP period = 16.8976 d (success=True)
#
# [INFO] Processing KIC 8246379 (label Prot=17.985 d)
# [INFO] QP-GP period = 19.0372 d (success=True)
#
# [INFO] Processing KIC 8247608 (label Prot=1.032 d)
# [INFO] QP-GP period = 0.9441 d (success=True)
#
# [INFO] Processing KIC 8263765 (label Prot=4.833 d)
# [INFO] QP-GP period = 5.5806 d (success=True)
#
# [INFO] Processing KIC 8264134 (label Prot=11.070 d)
# [INFO] QP-GP period = 10.8948 d (success=True)
#
# [INFO] Processing KIC 8264548 (label Prot=19.874 d)
# [INFO] QP-GP period = 25.8958 d (success=True)
#
# [INFO] Processing KIC 8296359 (label Prot=14.262 d)
# [INFO] QP-GP period = 14.2784 d (success=True)
#
# [INFO] Processing KIC 8327990 (label Prot=0.501 d)
# [INFO] QP-GP period = 0.5010 d (success=True)
#
# [INFO] Processing KIC 8329693 (label Prot=4.896 d)
# [INFO] QP-GP period = 4.8955 d (success=True)
#
# [INFO] Processing KIC 8331396 (label Prot=7.487 d)
# [INFO] QP-GP period = 8.4900 d (success=True)
#
# [INFO] Processing KIC 8358946 (label Prot=3.947 d)
# [INFO] QP-GP period = 4.5764 d (success=True)
#
# [INFO] Processing KIC 8360344 (label Prot=10.358 d)
# [INFO] QP-GP period = 10.4603 d (success=True)
#
# [INFO] Processing KIC 8394810 (label Prot=17.397 d)
# [INFO] QP-GP period = 19.5796 d (success=True)
#
# [INFO] Processing KIC 8395808 (label Prot=7.566 d)
# [INFO] QP-GP period = 8.9480 d (success=True)
#
# [INFO] Processing KIC 8415867 (label Prot=28.119 d)
# [INFO] QP-GP period = 31.3521 d (success=True)
#
# [INFO] Processing KIC 8416409 (label Prot=12.164 d)
# [INFO] QP-GP period = 15.1729 d (success=True)
#
# [INFO] Processing KIC 8418220 (label Prot=21.649 d)
# [INFO] QP-GP period = 37.2646 d (success=True)
#
# [INFO] Processing KIC 8424242 (label Prot=20.365 d)
# [INFO] QP-GP period = 23.4847 d (success=True)
#
# [INFO] Processing KIC 8431192 (label Prot=15.144 d)
# [INFO] QP-GP period = 18.6145 d (success=True)
#
# [INFO] Processing KIC 8442718 (label Prot=0.930 d)
# [INFO] QP-GP period = 0.9300 d (success=True)
#
# [INFO] Processing KIC 8476384 (label Prot=27.596 d)
# [INFO] QP-GP period = 33.8262 d (success=True)
#
# [INFO] Processing KIC 8487692 (label Prot=30.199 d)
# [INFO] QP-GP period = 32.8267 d (success=True)
#
# [INFO] Processing KIC 8494217 (label Prot=5.835 d)
# [INFO] QP-GP period = 6.8662 d (success=True)
#
# [INFO] Processing KIC 8508360 (label Prot=22.770 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 8509736 (label Prot=3.441 d)
# [INFO] QP-GP period = 5.8724 d (success=True)
#
# [INFO] Processing KIC 8509824 (label Prot=2.319 d)
# [INFO] QP-GP period = 3.7310 d (success=True)
#
# [INFO] Processing KIC 8545795 (label Prot=17.196 d)
# [INFO] QP-GP period = 19.6189 d (success=True)
#
# [INFO] Processing KIC 8554446 (label Prot=13.659 d)
# [INFO] QP-GP period = 15.9366 d (success=True)
#
# [INFO] Processing KIC 8557171 (label Prot=24.913 d)
# [INFO] QP-GP period = 37.3858 d (success=True)
#
# [INFO] Processing KIC 8560652 (label Prot=15.114 d)
# [INFO] QP-GP period = 15.2977 d (success=True)
#
# [INFO] Processing KIC 8564261 (label Prot=16.428 d)
# [INFO] QP-GP period = 18.4690 d (success=True)
#
# [INFO] Processing KIC 8564441 (label Prot=5.956 d)
# [INFO] QP-GP period = 6.3393 d (success=True)
#
# [INFO] Processing KIC 8564484 (label Prot=14.042 d)
# [INFO] QP-GP period = 17.4622 d (success=True)
#
# [INFO] Processing KIC 8565235 (label Prot=24.546 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 8574557 (label Prot=10.487 d)
# [INFO] QP-GP period = 13.2141 d (success=True)
#
# [INFO] Processing KIC 8582151 (label Prot=10.777 d)
# [INFO] QP-GP period = 11.9529 d (success=True)
#
# [INFO] Processing KIC 8590354 (label Prot=11.387 d)
# [INFO] QP-GP period = 12.0362 d (success=True)
#
# [INFO] Processing KIC 8621739 (label Prot=0.922 d)
# [INFO] QP-GP period = 0.9224 d (success=True)
#
# [INFO] Processing KIC 8624918 (label Prot=30.968 d)
# [INFO] QP-GP period = 33.7148 d (success=True)
#
# [INFO] Processing KIC 8625793 (label Prot=32.209 d)
# [INFO] QP-GP period = 34.3432 d (success=True)
#
# [INFO] Processing KIC 8629722 (label Prot=8.623 d)
# [INFO] QP-GP period = 11.7951 d (success=True)
#
# [INFO] Processing KIC 8635480 (label Prot=6.804 d)
# [INFO] QP-GP period = 9.2235 d (success=True)
#
# [INFO] Processing KIC 8636245 (label Prot=4.583 d)
# [INFO] QP-GP period = 6.5534 d (success=True)
#
# [INFO] Processing KIC 8653845 (label Prot=27.990 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 8673358 (label Prot=1.032 d)
# [INFO] QP-GP period = 2.3050 d (success=True)
#
# [INFO] Processing KIC 8673891 (label Prot=14.927 d)
# [INFO] QP-GP period = 18.5071 d (success=True)
#
# [INFO] Processing KIC 8686010 (label Prot=20.371 d)
# [INFO] QP-GP period = 37.5891 d (success=True)
#
# [INFO] Processing KIC 8687869 (label Prot=11.391 d)
# [INFO] QP-GP period = 11.5905 d (success=True)
#
# [INFO] Processing KIC 8717773 (label Prot=6.777 d)
# [INFO] QP-GP period = 8.4239 d (success=True)
#
# [INFO] Processing KIC 8749306 (label Prot=10.833 d)
# [INFO] QP-GP period = 10.4515 d (success=True)
#
# [INFO] Processing KIC 8758021 (label Prot=31.599 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 8771592 (label Prot=25.508 d)
# [INFO] QP-GP period = 37.1774 d (success=True)
#
# [INFO] Processing KIC 8772148 (label Prot=21.915 d)
# [INFO] QP-GP period = 39.1299 d (success=True)
#
# [INFO] Processing KIC 8804147 (label Prot=38.530 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 8806713 (label Prot=30.867 d)
# [INFO] QP-GP period = 37.6131 d (success=True)
#
# [INFO] Processing KIC 8813055 (label Prot=23.806 d)
# [INFO] QP-GP period = 23.8678 d (success=True)
#
# [INFO] Processing KIC 8824848 (label Prot=2.990 d)
# [INFO] QP-GP period = 3.4268 d (success=True)
#
# [INFO] Processing KIC 8841211 (label Prot=32.477 d)
# [INFO] QP-GP period = 37.3949 d (success=True)
#
# [INFO] Processing KIC 8843859 (label Prot=10.344 d)
# [INFO] QP-GP period = 10.2352 d (success=True)
#
# [INFO] Processing KIC 8847951 (label Prot=5.929 d)
# [INFO] QP-GP period = 7.5505 d (success=True)
#
# [INFO] Processing KIC 8873448 (label Prot=3.456 d)
# [INFO] QP-GP period = 3.8902 d (success=True)
#
# [INFO] Processing KIC 8894525 (label Prot=10.729 d)
# [INFO] QP-GP period = 10.9127 d (success=True)
#
# [INFO] Processing KIC 8914991 (label Prot=10.253 d)
# [INFO] QP-GP period = 12.0615 d (success=True)
#
# [INFO] Processing KIC 8916411 (label Prot=0.883 d)
# [INFO] QP-GP period = 0.8830 d (success=True)
#
# [INFO] Processing KIC 8936624 (label Prot=17.113 d)
# [INFO] QP-GP period = 18.9709 d (success=True)
#
# [INFO] Processing KIC 8938890 (label Prot=15.049 d)
# [INFO] QP-GP period = 14.1175 d (success=True)
#
# [INFO] Processing KIC 8939987 (label Prot=33.567 d)
# [INFO] QP-GP period = 36.9732 d (success=True)
#
# [INFO] Processing KIC 8940708 (label Prot=19.006 d)
# [INFO] QP-GP period = 23.1310 d (success=True)
#
# [INFO] Processing KIC 8959288 (label Prot=9.964 d)
# [INFO] QP-GP period = 12.8995 d (success=True)
#
# [INFO] Processing KIC 8962137 (label Prot=22.603 d)
# [INFO] QP-GP period = 39.8362 d (success=True)
#
# [INFO] Processing KIC 8971874 (label Prot=24.081 d)
# [INFO] QP-GP period = 36.3505 d (success=True)
#
# [INFO] Processing KIC 8985384 (label Prot=22.628 d)
# [INFO] QP-GP period = 39.8355 d (success=True)
#
# [INFO] Processing KIC 9012171 (label Prot=27.422 d)
# [INFO] QP-GP period = 31.6346 d (success=True)
#
# [INFO] Processing KIC 9017238 (label Prot=34.067 d)
# [INFO] QP-GP period = 37.4425 d (success=True)
#
# [INFO] Processing KIC 9029517 (label Prot=25.539 d)
# [INFO] QP-GP period = 37.5436 d (success=True)
#
# [INFO] Processing KIC 9029518 (label Prot=2.428 d)
# [INFO] QP-GP period = 3.5025 d (success=True)
#
# [INFO] Processing KIC 9034074 (label Prot=11.058 d)
# [INFO] QP-GP period = 11.9354 d (success=True)
#
# [INFO] Processing KIC 9073131 (label Prot=14.431 d)
# [INFO] QP-GP period = 16.9740 d (success=True)
#
# [INFO] Processing KIC 9075993 (label Prot=12.010 d)
# [INFO] QP-GP period = 13.0029 d (success=True)
#
# [INFO] Processing KIC 9095110 (label Prot=5.274 d)
# [INFO] QP-GP period = 5.9198 d (success=True)
#
# [INFO] Processing KIC 9097199 (label Prot=3.737 d)
# [INFO] QP-GP period = 4.2374 d (success=True)
#
# [INFO] Processing KIC 9109003 (label Prot=28.392 d)
# [INFO] QP-GP period = 37.4168 d (success=True)
#
# [INFO] Processing KIC 9141609 (label Prot=27.996 d)
# [INFO] QP-GP period = 34.6550 d (success=True)
#
# [INFO] Processing KIC 9141881 (label Prot=4.112 d)
# [INFO] QP-GP period = 4.6286 d (success=True)
#
# [INFO] Processing KIC 9142714 (label Prot=10.922 d)
# [INFO] QP-GP period = 11.9487 d (success=True)
#
# [INFO] Processing KIC 9149986 (label Prot=1.434 d)
# [INFO] QP-GP period = 1.4559 d (success=True)
#
# [INFO] Processing KIC 9157703 (label Prot=20.320 d)
# [INFO] QP-GP period = 20.6580 d (success=True)
#
# [INFO] Processing KIC 9176383 (label Prot=39.640 d)
# [INFO] QP-GP period = 37.5076 d (success=True)
#
# [INFO] Processing KIC 9179256 (label Prot=24.087 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9182484 (label Prot=3.930 d)
# [INFO] QP-GP period = 4.4284 d (success=True)
#
# [INFO] Processing KIC 9201411 (label Prot=37.639 d)
# [INFO] QP-GP period = 37.2345 d (success=True)
#
# [INFO] Processing KIC 9201790 (label Prot=26.063 d)
# [INFO] QP-GP period = 38.0492 d (success=True)
#
# [INFO] Processing KIC 9216773 (label Prot=31.928 d)
# [INFO] QP-GP period = 35.9019 d (success=True)
#
# [INFO] Processing KIC 9224698 (label Prot=6.877 d)
# [INFO] QP-GP period = 10.9943 d (success=True)
#
# [INFO] Processing KIC 9226525 (label Prot=14.467 d)
# [INFO] QP-GP period = 16.9227 d (success=True)
#
# [INFO] Processing KIC 9229171 (label Prot=6.979 d)
# [INFO] QP-GP period = 10.8647 d (success=True)
#
# [INFO] Processing KIC 9283985 (label Prot=4.656 d)
# [INFO] QP-GP period = 4.6569 d (success=True)
#
# [INFO] Processing KIC 9287933 (label Prot=20.416 d)
# [INFO] QP-GP period = 22.9051 d (success=True)
#
# [INFO] Processing KIC 9291754 (label Prot=33.219 d)
# [INFO] QP-GP period = 37.3379 d (success=True)
#
# [INFO] Processing KIC 9303842 (label Prot=7.881 d)
# [INFO] QP-GP period = 9.3955 d (success=True)
#
# [INFO] Processing KIC 9326538 (label Prot=25.945 d)
# [INFO] QP-GP period = 37.6425 d (success=True)
#
# [INFO] Processing KIC 9347432 (label Prot=22.366 d)
# [INFO] QP-GP period = 22.1835 d (success=True)
#
# [INFO] Processing KIC 9347979 (label Prot=29.371 d)
# [INFO] QP-GP period = 31.4533 d (success=True)
#
# [INFO] Processing KIC 9368360 (label Prot=12.776 d)
# [INFO] QP-GP period = 14.3316 d (success=True)
#
# [INFO] Processing KIC 9392121 (label Prot=13.768 d)
# [INFO] QP-GP period = 14.2086 d (success=True)
#
# [INFO] Processing KIC 9411621 (label Prot=19.113 d)
# [INFO] QP-GP period = 36.9990 d (success=True)
#
# [INFO] Processing KIC 9427948 (label Prot=26.903 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9456901 (label Prot=6.514 d)
# [INFO] QP-GP period = 7.1192 d (success=True)
#
# [INFO] Processing KIC 9456932 (label Prot=0.530 d)
# [INFO] QP-GP period = 0.5302 d (success=True)
#
# [INFO] Processing KIC 9474239 (label Prot=6.135 d)
# [INFO] QP-GP period = 7.8694 d (success=True)
#
# [INFO] Processing KIC 9474309 (label Prot=32.474 d)
# [INFO] QP-GP period = 37.1337 d (success=True)
#
# [INFO] Processing KIC 9481106 (label Prot=11.271 d)
# [INFO] QP-GP period = 11.8701 d (success=True)
#
# [INFO] Processing KIC 9481887 (label Prot=16.623 d)
# [INFO] QP-GP period = 19.2287 d (success=True)
#
# [INFO] Processing KIC 9487552 (label Prot=15.603 d)
# [INFO] QP-GP period = 15.6424 d (success=True)
#
# [INFO] Processing KIC 9512046 (label Prot=24.970 d)
# [INFO] QP-GP period = 38.0629 d (success=True)
#
# [INFO] Processing KIC 9512119 (label Prot=25.435 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9512162 (label Prot=19.420 d)
# [INFO] QP-GP period = 22.7917 d (success=True)
#
# [INFO] Processing KIC 9519275 (label Prot=18.021 d)
# [INFO] QP-GP period = 21.1321 d (success=True)
#
# [INFO] Processing KIC 9520539 (label Prot=17.146 d)
# [INFO] QP-GP period = 19.6939 d (success=True)
#
# [INFO] Processing KIC 9529322 (label Prot=30.235 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9529741 (label Prot=24.829 d)
# [INFO] QP-GP period = 39.3506 d (success=True)
#
# [INFO] Processing KIC 9529787 (label Prot=31.670 d)
# [INFO] QP-GP period = 33.5908 d (success=True)
#
# [INFO] Processing KIC 9533670 (label Prot=11.435 d)
# [INFO] QP-GP period = 13.5570 d (success=True)
#
# [INFO] Processing KIC 9536371 (label Prot=26.058 d)
# [INFO] QP-GP period = 37.5698 d (success=True)
#
# [INFO] Processing KIC 9588514 (label Prot=20.505 d)
# [INFO] QP-GP period = 24.8115 d (success=True)
#
# [INFO] Processing KIC 9590661 (label Prot=3.091 d)
# [INFO] QP-GP period = 3.6402 d (success=True)
#
# [INFO] Processing KIC 9594726 (label Prot=9.658 d)
# [INFO] QP-GP period = 13.2342 d (success=True)
#
# [INFO] Processing KIC 9644954 (label Prot=31.839 d)
# [INFO] QP-GP period = 34.8757 d (success=True)
#
# [INFO] Processing KIC 9657772 (label Prot=14.643 d)
# [INFO] QP-GP period = 17.5284 d (success=True)
#
# [INFO] Processing KIC 9662116 (label Prot=22.442 d)
# [INFO] QP-GP period = 37.0875 d (success=True)
#
# [INFO] Processing KIC 9663658 (label Prot=18.901 d)
# [INFO] QP-GP period = 21.0627 d (success=True)
#
# [INFO] Processing KIC 9673870 (label Prot=4.992 d)
# [INFO] QP-GP period = 5.5686 d (success=True)
#
# [INFO] Processing KIC 9673891 (label Prot=3.107 d)
# [INFO] QP-GP period = 3.1070 d (success=True)
#
# [INFO] Processing KIC 9696929 (label Prot=31.032 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9701988 (label Prot=20.273 d)
# [INFO] QP-GP period = 20.1622 d (success=True)
#
# [INFO] Processing KIC 9702201 (label Prot=18.166 d)
# [INFO] QP-GP period = 21.3328 d (success=True)
#
# [INFO] Processing KIC 9716008 (label Prot=10.067 d)
# [INFO] QP-GP period = 14.3196 d (success=True)
#
# [INFO] Processing KIC 9717563 (label Prot=16.189 d)
# [INFO] QP-GP period = 19.6015 d (success=True)
#
# [INFO] Processing KIC 9724348 (label Prot=12.413 d)
# [INFO] QP-GP period = 14.8542 d (success=True)
#
# [INFO] Processing KIC 9726020 (label Prot=2.133 d)
# [INFO] QP-GP period = 2.1318 d (success=True)
#
# [INFO] Processing KIC 9778224 (label Prot=37.448 d)
# [INFO] QP-GP period = 37.5867 d (success=True)
#
# [INFO] Processing KIC 9821337 (label Prot=19.095 d)
# [INFO] QP-GP period = 33.7227 d (success=True)
#
# [INFO] Processing KIC 9823103 (label Prot=15.993 d)
# [INFO] QP-GP period = 16.7539 d (success=True)
#
# [INFO] Processing KIC 9845245 (label Prot=3.649 d)
# [INFO] QP-GP period = 4.2398 d (success=True)
#
# [INFO] Processing KIC 9846463 (label Prot=18.973 d)
# [INFO] QP-GP period = 22.1778 d (success=True)
#
# [INFO] Processing KIC 9880787 (label Prot=20.927 d)
# [INFO] QP-GP period = 31.6571 d (success=True)
#
# [INFO] Processing KIC 9881650 (label Prot=28.315 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9882662 (label Prot=28.075 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9887628 (label Prot=19.355 d)
# [INFO] QP-GP period = 19.5848 d (success=True)
#
# [INFO] Processing KIC 9893496 (label Prot=25.235 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9897060 (label Prot=29.122 d)
# [INFO] QP-GP period = 39.5403 d (success=True)
#
# [INFO] Processing KIC 9906862 (label Prot=22.069 d)
# [INFO] QP-GP period = 40.0000 d (success=True)
#
# [INFO] Processing KIC 9909232 (label Prot=27.437 d)
# [INFO] QP-GP period = 27.2668 d (success=True)
#
# [INFO] Processing KIC 9912689 (label Prot=15.544 d)
# [INFO] QP-GP period = 18.4340 d (success=True)
#
# [INFO] Processing KIC 9935067 (label Prot=15.791 d)
# [INFO] QP-GP period = 18.0691 d (success=True)
#
# [INFO] Processing KIC 9959022 (label Prot=12.740 d)
# [INFO] QP-GP period = 15.0015 d (success=True)
#
# [INFO] Processing KIC 9970848 (label Prot=22.207 d)
# [INFO] QP-GP period = 35.6430 d (success=True)
#
# [INFO] Processing KIC 9993819 (label Prot=23.291 d)
# [INFO] QP-GP period = 26.1589 d (success=True)
#
# [INFO] Processing KIC 9994206 (label Prot=18.306 d)
# [INFO] QP-GP period = 21.3960 d (success=True)
#
# [INFO] Processing KIC 9995419 (label Prot=10.873 d)
# [INFO] QP-GP period = 11.0912 d (success=True)
#
# [INFO] Processing KIC 10002203 (label Prot=19.165 d)
# [INFO] QP-GP period = 19.7988 d (success=True)
#
# [INFO] Saved baseline results to: /Users/Zhuanz/Documents/Dissertation/data/kepler/baseline_periods_ls_acf.csv
# [INFO] Total stars processed (rows in output) = 500
