# %%
import sys
from pathlib import Path

# 确保在项目根目录下（有 src/ 的那一层）
# %cd /Users/Zhuanz/Documents/Dissertation

# 把项目根目录加进 sys.path，确保能 import src.XXX
import sys
sys.path.insert(0, str(Path.cwd()))

from src.traditional.run_baseline_periods import main

# 模拟命令行参数：["run_baseline_periods.py", "--max-targets", "50"]
sys.argv = ["run_baseline_periods.py", "--max-targets", "50"]
main()
# Out:
# /Users/Zhuanz/Documents/Dissertation
# [INFO] Found 50 npz lightcurves in /Users/Zhuanz/Documents/Dissertation/data/kepler/lightcurves
#
# [INFO] Processing KIC 893647 (label Prot=8.829 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 2019900 (label Prot=5.975 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 2556279 (label Prot=3.317 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 2695222 (label Prot=3.702 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 2831370 (label Prot=19.630 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 2832484 (label Prot=3.646 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3222610 (label Prot=4.910 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3236788 (label Prot=5.429 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3242050 (label Prot=12.932 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3327068 (label Prot=4.519 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3330261 (label Prot=26.347 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3540780 (label Prot=26.697 d)
# [INFO] QP-GP period = nan d (success=False)
#
# [INFO] Processing KIC 3648721 (label Prot=2.523 d)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      13 # 模拟命令行参数：["run_baseline_periods.py", "--max-targets", "50"]
#      14 sys.argv = ["run_baseline_periods.py", "--max-targets", "50"]
# ---> 15 main()
#
# File ~/Documents/Dissertation/src/traditional/run_baseline_periods.py:166, in main()
#     164 if not args.skip_gps:
#     165     try:
# --> 166         prot_gps, q_gps, _meta = estimate_period_gps(
#     167             t, flux,
#     168             min_period=0.5,
#     169             max_period=40.0,
#     170         )
#     171     except Exception as e:
#     172         print(f"[WARN] GPS method failed for KIC {kic}: {e}")
#
# File ~/Documents/Dissertation/src/traditional/wavelet_gps.py:211, in estimate_period_gps(time, flux, min_period, max_period, n_periods, smooth_sigma, prominence_frac)
#     209 # 使用手写 CWT
#     210 try:
# --> 211     cwt_coef = _cwt_morlet_manual(y_u, widths)
#     212 except Exception as e:
#     213     print(f"[WARN] Manual CWT failed: {e}")
#
# File ~/Documents/Dissertation/src/traditional/wavelet_gps.py:142, in _cwt_morlet_manual(y, widths)
#     140     psi = _morlet_wavelet(M, scale=w, w=6.0)
#     141     # 卷积，mode="same" 保持和 y 同长度
# --> 142     conv = signal.fftconvolve(y, psi[::-1], mode="same")
#     143     coefs[i, :] = conv
#     145 return coefs
#
# File /opt/miniconda3/envs/workspace/lib/python3.12/site-packages/scipy/signal/_signaltools.py:732, in fftconvolve(in1, in2, mode, axes)
#     727 shape = [max((s1[i], s2[i])) if i not in axes else s1[i] + s2[i] - 1
#     728          for i in range(in1.ndim)]
#     730 ret = _freq_domain_conv(xp, in1, in2, axes, shape, calc_fast_len=True)
# --> 732 return _apply_conv_mode(ret, s1, s2, mode, axes, xp=xp)
#
# File /opt/miniconda3/envs/workspace/lib/python3.12/site-packages/scipy/signal/_signaltools.py:577, in _apply_conv_mode(ret, s1, s2, mode, axes, xp)
#     572         ret = ret[fslice]
#     574     return ret
# --> 577 def _apply_conv_mode(ret, s1, s2, mode, axes, xp):
#     578     """Calculate the convolution result shape based on the `mode` argument.
#     579
#     580     Returns the result sliced to the correct size for the given mode.
#    (...)    600
#     601     """
#     602     if mode == "full":
#
# KeyboardInterrupt:
